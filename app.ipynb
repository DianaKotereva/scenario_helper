# %%
from app import app
import uuid
# Out:
# Введите токен DeepSeek: sk-74a6644f81dc41228a6ed515fbfad685
# 2025-10-11 11:14:05,911 - src.agent.vector_store.vector_store - INFO - Loading existing FAISS index from data\vector_store.faiss\shadow_and_flame_.faiss
# 2025-10-11 11:14:05,977 - faiss.loader - INFO - Loading faiss with AVX2 support.
# 2025-10-11 11:14:06,112 - faiss.loader - INFO - Successfully loaded faiss with AVX2 support.

# %%
inputs = {"user_question": "Сделай детальное описание Эктелиона. Его характер, его симпатии, его антипатии, кого он любит, кого ненавидит"}
state_res = app.invoke(inputs)
# Out:
# 2025-10-10 20:41:50,036 - httpx - INFO - HTTP Request: POST https://api.deepseek.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'reasoning': 'Контекст полностью пуст - отсутствует какая-либо информация об Эктелионе. Для создания детального описания его характера, симпатий, антипатий, любви и ненависти необходимо собрать базовую информацию о персонаже. Без исходных данных невозможно дать содержательный ответ на вопрос пользователя.', 'next_step': 'SEARCH', 'to_collect': 'Собрать базовую информацию об Эктелионе: кто он (персонаж из игры/книги/фильма), его происхождение, основные черты характера, ключевые отношения с другими персонажами, значимые события в его истории, мотивации и ценности. Особое внимание уделить информации о его симпатиях и антипатиях, любимых и ненавистных персонажах.'}
# Сделай детальное описание Эктелиона. Его характер, его симпатии, его антипатии, кого он любит, кого ненавидит
# ...

# %%
print(state_res['final_answer'])
# Out:
# На основе анализа предоставленного контекста можно составить следующее детальное описание Эктелиона:
#
# **ХАРАКТЕР И ЛИЧНЫЕ КАЧЕСТВА:**
# 1. Талантливый и прилежный воин: описывается как «талантливый новичок, успешно выполняет приёмы» и «невозмутимый и прилежный» во время тренировок
# 2. Эмоционально уязвимый: «расстроен из-за конфликта между Нолдор и Ваниар» и демонстрирует сложные эмоциональные реакции на события в Тирионе
# 3. Решительный и принципиальный: демонстрирует высокое мастерство владения мечом и щитом, но «отказывается от предложения стать заместителем в Чёрных Стражах, объявляя о своём уходе»
# 4. Профессионально собранный: сохраняет самообладание в стрессовых ситуациях, проявляет формальность и деловитость в служебных взаимодействиях
#
# **СИМПАТИИ И ПРИВЯЗАННОСТИ:**
# 1. Глубокая духовная преданность Варде: проявляет «восторг одновременно, на грани с экстазом» при встрече с Вардой и использует «заклинательную песню, обращаясь к образу Валар»
# ...

# %%
state_res
# Out:
# {'user_question': 'Сделай детальное описание Эктелиона. Его характер, его симпатии, его антипатии, кого он любит, кого ненавидит',
#  'thoughts': ['Контекст полностью пуст - отсутствует какая-либо информация об Эктелионе. Для создания детального описания его характера, симпатий, антипатий, любви и ненависти необходимо собрать базовую информацию о персонаже. Без исходных данных невозможно дать содержательный ответ на вопрос пользователя.',
# ...

# %%
inputs = {"user_question": "Сколько детей родила Нерданель?"}
state_res = app.invoke(inputs)
# Out:
# 2025-10-10 20:45:13,912 - httpx - INFO - HTTP Request: POST https://api.deepseek.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'reasoning': 'Контекст полностью пуст - отсутствует какая-либо информация о Нерданель и количестве её детей. Для ответа на вопрос пользователя необходимо найти достоверные данные о биографии Нерданель, в частности информацию о её детях. Без этого невозможно дать какой-либо осмысленный ответ.', 'next_step': 'SEARCH', 'to_collect': 'Найти информацию о Нерданель: установить её полную идентификацию (кто это - историческая личность, персонаж, современная личность), найти биографические данные с акцентом на информацию о детях, включая их количество, имена и даты рождения. Если это персонаж, указать произведение/источник.'}
# Сколько детей родила Нерданель?
# 2025-10-10 20:45:23,003 - httpx - INFO - HTTP Request: POST https://api.proxyapi.ru/openai/v1/embeddings "HTTP/1.1 200 OK"
# ...

# %%
print(state_res['final_answer'])
# Out:
# На основе предоставленного контекста невозможно точно определить, сколько детей родила Нерданель. Информация является фрагментарной и содержит противоречия:
#
# 1. **Данные о детях в контексте:**
#    - В разделе действий Нерданель указано, что она "рожает сына, предлагает имя Майтимо" и упоминается как "мать Аэнариона"
#    - В разделе действий Макалаурэ говорится, что он "упоминается как будущий сын Чародея и Нерданель"
#    - В разделе взаимодействия между Макалаурэ и Нерданель указано: "Нерданель узнает, что у нее будет еще один сын, Макалаурэ"
#
# 2. **Проблема идентификации персонажей:**
#    - Согласно анализу контекста, Майтимо и Аэнарион — это ОДИН И ТОТ ЖЕ персонаж, сын Нерданель и Малекита
#    - В главе 25 прямо указывается: «Он называет его Аэнарионом... Нерданель, чувствуя себя хорошо, предлагает имя Майтимо»
#    - Оба имени относятся к одному ребенку — первенцу Нерданель
#
# 3. **Недостаточность информации:**
# ...

# %%
state_res
# Out:
# {'user_question': 'Сколько детей родила Нерданель?',
#  'thoughts': ['Контекст полностью пуст - отсутствует какая-либо информация о Нерданель и количестве её детей. Для ответа на вопрос пользователя необходимо найти достоверные данные о биографии Нерданель, в частности информацию о её детях. Без этого невозможно дать какой-либо осмысленный ответ.',
#   'Проанализировав собранный контекст, я вижу, что информация о детях Нерданель действительно фрагментарна и противоречива. В контексте упоминаются: сын с именем Майтимо, Аэнарион как её сын, и Макалаурэ как будущий сын. Однако контекст не позволяет установить точное количество детей - упоминания могут относиться к одному и тому же ребенку под разными именами, либо информация может быть неполной. Также отсутствует систематизированный перечень всех детей Нерданель и хронологическая определенность. Контекст прямо указывает на недостаточность данных для точного ответа.',
# ...

# %%
inputs = {"user_question": "Как Малекит сделал Нерданели предложение?"}
state_res = app.invoke(inputs)
# Out:
# 2025-10-10 20:59:42,084 - httpx - INFO - HTTP Request: POST https://api.deepseek.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'reasoning': 'Контекст полностью пуст - отсутствует какая-либо информация о Малеките, Нерданели или их отношениях. Нет данных о том, кто эти персонажи, в каком контексте они существуют (книга, фильм, игра, реальные люди), и тем более нет никакой информации о предложении. Для ответа на вопрос требуется собрать базовую информацию об этих персонажах и детали их отношений.', 'next_step': 'SEARCH', 'to_collect': 'Необходимо собрать информацию: 1) Кто такие Малекит и Нерданели - их происхождение, контекст (литературные персонажи, исторические личности, персонажи игр и т.д.); 2) Характер их отношений; 3) Конкретные детали о том, как Малекит сделал предложение Нерданели - обстоятельства, место, время, способ предложения, реакция Нерданели.'}
# Как Малекит сделал Нерданели предложение?
# ...

# %%
print(state_res['final_answer'])
# Out:
# Согласно анализу контекста книги, предложение Малекита Нерданели было представлено как часть их совместной работы и постепенно развивающихся отношений:
#
# 1. **Совместная творческая работа как основа**: Малекит и Нерданель вместе работали над статуей из белого гранита, где обсуждали детали подарков для короля и королевы. В ходе этой работы Малекит демонстрировал Нерданель чертеж многозарядного арбалета и выражал скрытые послания через статую, что создавало интеллектуальную и эмоциональную связь между ними.
#
# 2. **Прямое предложение и обсуждение будущего**: В описании взаимодействия указано, что 'Малекит предлагает Нерданель стать его женой и будущей королевой, целует её и обсуждает их будущее вместе'. Это свидетельствует о формальном предложении брака, сопровождаемом физическим проявлением чувств (поцелуем) и практическим обсуждением их совместной судьбы.
#
# ...

# %%
inputs = {"user_question": "Как относилcя Лаурэфиндэ к Малекиту?"}
state_res = app.invoke(inputs)
# Out:
# 2025-10-10 20:21:59,009 - httpx - INFO - HTTP Request: POST https://api.deepseek.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'reasoning': 'Контекст полностью пуст - отсутствует какая-либо информация о Лаурэфиндэ, Малеките или их взаимоотношениях. Для ответа на вопрос пользователя необходимо собрать базовую информацию об этих персонажах и их взаимодействиях. Без контекста невозможно определить, являются ли они историческими личностями, литературными персонажами, мифологическими фигурами или кем-то другим.', 'next_step': 'SEARCH', 'to_collect': 'Собрать информацию о Лаурэфиндэ и Малеките: кто они (исторические личности, литературные персонажи, мифологические фигуры), в каком контексте они существуют (история, литература, мифология, игры), и конкретные сведения об их взаимоотношениях - как Лаурэфиндэ относился к Малекиту, какие были между ними взаимодействия, характер их отношений.'}
# Как относилcя Лаурэфиндэ к Малекиту?
# ...

# %%
print(state_res['final_answer'])
# Out:
# Согласно представленному контексту, отношения Лаурэфиндэ к Малекиту характеризуются сложной системой взаимного уважения, лояльности и профессионального сотрудничества, основанной на следующих ключевых аспектах:
#
# 1. **Лояльность и служение**: Лаурэфиндэ демонстрирует формальную преданность Малекиту через символические акты. Согласно контексту, 'Лаурэфиндэ присягнул Малекиту и появился в его цветах, что символизирует создание своего Дома', что указывает на установление вассально-сюзеренных отношений.
#
# 2. **Профессиональное сотрудничество и доверие**: Малекит доверяет Лаурэфиндэ важные обязанности, включая 'командование войсками на время своего отсутствия' и обсуждает с ним 'должность командира Чёрных Стражей и наставника будущих наследников', что свидетельствует о высоком уровне профессионального доверия.
#
# ...

# %%
inputs = {"user_question": "Кто такой Арафинвэ?"}
state_res = app.invoke(inputs)
# Out:
# 2025-10-10 20:23:10,696 - httpx - INFO - HTTP Request: POST https://api.deepseek.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'reasoning': 'Контекст полностью пуст - нет никакой информации об Арафинвэ. Для ответа на вопрос пользователя необходимо собрать базовую информацию: кто это, в какой области/контексте упоминается (история, литература, мифология, современность и т.д.), основные характеристики или достижения этой личности.', 'next_step': 'SEARCH', 'to_collect': 'Собрать базовую информацию об Арафинвэ: установить, кто это (человек, персонаж, историческая личность), в каком контексте упоминается, основные характеристики, значимость. Определить область знаний, к которой относится Арафинвэ.'}
# Кто такой Арафинвэ?
# 2025-10-10 20:23:19,241 - httpx - INFO - HTTP Request: POST https://api.proxyapi.ru/openai/v1/embeddings "HTTP/1.1 200 OK"
# 2025-10-10 20:23:19,801 - httpx - INFO - HTTP Request: POST https://api.deepseek.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...

# %%
print(state_res['final_answer'])
# Out:
# На основе анализа предоставленного контекста можно дать следующую характеристику Арафинвэ:
#
# 1. **Происхождение и семейные связи**: Арафинвэ является младшим сыном короля Финвэ и Индис, новорожденным братом Нолофинвэ. Он описывается как «здоровый и тихий ребёнок» и также является внуком Ингвэ, короля Ваниар, что подтверждается тем, что «Ингвэ беспокоится о здоровье новорожденного внука Арафинвэ».
#
# 2. **Политическая роль и амбиции**: Арафинвэ рассматривается как потенциальный наследник престола Нолдор, особенно после конфликта с братом Нолофинвэ. В контексте указано: «Будущий наследный принц, которому нужно подобрать достойное окружение». Его политические взгляды антипатичны к Феанаро, как отмечено: «Ненавидел Феанаро, получил от него шпагу, поклялся отомстить» и «Распространяет слухи о Феанаро, пытается укрепить свою позицию в политическом конфликте».
#
# ...

# %%
inputs = {"user_question": "Кто такой Арафинвэ? Какие отношения между ним и Эктелионом?"}
state_res = app.invoke(inputs)
# Out:
# 2025-10-10 20:25:19,165 - httpx - INFO - HTTP Request: POST https://api.deepseek.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'reasoning': 'Контекст полностью пуст - отсутствует какая-либо информация о персонажах Арафинвэ и Эктелионе. Невозможно определить, кто эти персонажи, из какой они вселенной (литература, игры, мифология и т.д.), какие между ними отношения. Для ответа на вопрос пользователя требуется собрать базовую информацию об этих персонажах.', 'next_step': 'SEARCH', 'to_collect': 'Необходимо собрать информацию о персонажах Арафинвэ и Эктелионе: 1) Определить источник происхождения этих персонажей (произведение, вселенная); 2) Основные характеристики Арафинвэ - кто он, его роль, значимость; 3) Основные характеристики Эктелиона - кто он, его роль; 4) Характер отношений между ними - друзья, враги, родственники, союзники и т.д.; 5) Конкретные события или взаимодействия, характеризующие их отношения.'}
# Кто такой Арафинвэ? Какие отношения между ним и Эктелионом?
# ...

# %%
print(state_res['final_answer'])
# Out:
# На основе анализа контекста можно дать следующий ответ:
#
# 1. **Арафинвэ - младший сын Финвэ и Индис, потенциальный наследный принц Нолдор:**
#    - Согласно описанию: "Новорожденный сын Индис и Финвэ. Описывается как здоровый и тихий ребёнок. Будущий наследный принц"
#    - "Младший брат Нолофинвэ, ученик Эктелиона. Тренируется с мечом, но его движения неумелы. Объект внимания деда Ингвэ как потенциальный наследник"
#    - "Упоминается как возможный наследник вместо Нолофинвэ, которого Ингвэ и Финвэ начали продвигать"
#
# 2. **Отношения между Арафинвэ и Эктелионом - отношения ученика и наставника:**
#    - Из взаимодействий: "Эктелион тренирует Арафинвэ", "Эктелион теперь будет обучать Арафинвэ", "Эктелион проводит тренировки для Арафинвэ"
#    - "Арафинвэ просит Эктелиона помочь ему в подготовке к будущему конфликту" и "Арафинвэ соглашается с мнением Эктелиона о необходимости расследования"
# ...
